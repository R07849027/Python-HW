# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("http://data.ntpc.gov.tw/od/data/api/54DDDC93-589C-4858-9C95-18B2046CC1FC?$format=csv")

# %% [markdown]
# ### 資料為新北市政府資料開放平台："新北市公共自行車租賃系統(YouBike)"
#
# ### 若當地的youbike停車格數越多，是否代表當地youbike可借車位數越多呢？
#
# 藉由線性迴歸分析，透過 場站總停車格 來預測 可借車位數

# %%
df.head()
#tot 為 場站總停車格
#sbi 為 可借車位數
# Out:
#     sno     sna  tot  sbi sarea            mday        lat         lng  \
# 0  1001    大鵬華城   38   10   新店區  20190412070843  24.991160  121.533980
# 1  1002   汐止火車站   56   18   汐止區  20190412070819  25.068914  121.662748
# 2  1003   汐止區公所   46   18   汐止區  20190412070818  25.064162  121.658301
# 3  1004  國泰綜合醫院   56   13   汐止區  20190412070832  25.073150  121.662555
# 4  1005    裕隆公園   40   16   新店區  20190412070832  24.979649  121.546319
#
#                                 ar        sareaen                    snaen  \
# 0                  新北市新店區中正路700巷3號  Xindian Dist.         Dapeng Community
# 1                   南昌街/新昌路口(西側廣場)    Xizhi Dist.    Xizhi Railway Station
# 2  新台五路一段/仁愛路口(新台五路側汐止地政事務所前機車停車場)    Xizhi Dist.       Xizhi Dist. Office
# 3                      建成路78號對面停車場    Xizhi Dist.  Cathay General Hospital
# 4                    寶中路/品牌路口(東南側)  Xindian Dist.               Yulon Park
#
#                                                 aren  bemp  act
# ...

# %% [markdown]
# ### 先對 tot 做排序

# %%
df.sort_values(by=['tot'])
# Out:
#       sno            sna  tot  sbi sarea            mday        lat  \
# 456  1463          新泰游泳池   26    7   新莊區  20190415101819  25.045414
# 509  1516      成泰路一段(中油)   26   11   五股區  20190415101824  25.078430
# 208  1209       崇德橋東活動中心   26    3   汐止區  20190415101832  25.070512
# 405  1412   捷運大坪林站(1號出口)   28    2   新店區  20190415101743  24.982755
# 507  1514        延吉街47巷口   28   11   土城區  20190415101830  24.987690
# 334  1335         三重五常公園   28   17   三重區  20190415101845  25.080648
# 522  1614        中正路284巷   28    0   新店區  20190415101830  24.974700
# 204  1205           竹圍公園   28   11   淡水區  20190415101840  25.138234
# 493  1500         忠孝活動中心   28    8   永和區  20190415101834  25.016770
# 183  1184        中和地政事務所   28    0   中和區  20190415101845  24.990393
# 430  1437           成州國小   28   12   五股區  20190415101822  25.099230
# 376  1377         大庄一號公園   28   10   淡水區  20190415101833  25.181957
# 87   1088     秀得里(成功路二段)   28   19   永和區  20190415101823  25.000705
# ...

# %% [markdown]
# ### 繪製散佈圖，觀察原始資料中 tot 與 sbi 的關係

# %%
plt.scatter(df["tot"], df["sbi"])

# %% [markdown]
# #### 從圖中看來雖然前段資料很密集，但綜觀來看似乎有正相關

# %% [markdown]
# #### 計算原始資料的相關係數

# %%
x = np.array(df["tot"])
y = np.array(df["sbi"])
np.corrcoef([x,y])
# Out:
# array([[1.        , 0.42290569],
#        [0.42290569, 1.        ]])

# %% [markdown]
# #### 兩者相關係數 = 0.4229 (為正相關，但非高度相關)

# %% [markdown]
# ### 開始進行預測，將資料分為 70% training data 與 30% testing data

# %%
regr = LinearRegression()

# %%
#進行回歸前資料前處理
X = x.reshape(len(x), 1)

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 40)

# %% [markdown]
# ### 觀察 training data 與  testing data 的散佈情況

# %%
plt.scatter(x_train, y_train)

# %%
plt.scatter(x_test, y_test)

# %% [markdown]
# #### 從圖看來 training 與 testing 的趨勢均未偏離原始資料

# %% [markdown]
# ### 建立迴歸模型

# %%
regr.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# ### 生成預測值

# %%
Y_pred = regr.predict(x_test)

# %% [markdown]
# ## 作圖評估預測效果

# %%
plt.scatter(x_test, y_test)
plt.plot(x_test, Y_pred, 'r')

# %% [markdown]
# ## Error metrics

# %% [markdown]
# #### MAE

# %%
AE = 0
for i in range(len(Y_pred)):
     AE += abs(y_test[i] - Y_pred[i])
MAE = AE/len(Y_pred)
print("MAE 為",MAE)
# Out:
# MAE 為 7.40890075468784

# %% [markdown]
# #### MSE

# %%
SE = 0
for i in range(len(Y_pred)):
     SE += (y_test[i] - Y_pred[i])**2
MSE = SE/len(Y_pred)
print("MSE 為",MSE)
# Out:
# MSE 為 82.54065695130936

# %% [markdown]
# #### Error metrics 比較：
#
#      MAE 為最常用的 error metric 標準。而 MSE 由於是把差異平方，因此會把 outliers 所造成的 error 放大。MAE 為 7.4 代表預測值與實際值的平均絕對差異為 7.4。舉例來說，若我預測某地區 youbike 可借車數為 5，則實際可借數可能為 -2.4~12.4，也就是大約 0~12 台。

# %% [markdown]
# #### 結論：
#     散佈圖為testing data，紅色為預測迴歸線， 可以看到除了右上角的離群值以外，迴歸線與testing data的配適度還不錯。然而，雖然迴歸線的斜率與testing data正向趨勢相近，但隨著 tot(場站總停車格) 增加，預測值(線上的點)與實際值(testing data) 的距離越遠，代表 sbi (可借車位數)預測準確度可能隨著 tot (場站總停車格) 增加 而減少。但總結來說，確實可以利用總停車格數來約略估計當地的 youbike 可借車位數。
